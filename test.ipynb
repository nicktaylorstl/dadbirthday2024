# %%
import sqlite3

# Path to the SQLite database
db_path = r'D:\Documents\GFA\SportsPython\Basketball\dadbirthday2024\data\heat.db'

def select_from_database(sql_query):
    # Connect to the database
    conn = sqlite3.connect(db_path)
    cursor = conn.cursor()

    cursor.execute(sql_query)
    rows = cursor.fetchall()

    for row in rows:
        print(row)

    cursor.close()
    conn.close()

# %%
# Example SQL SELECT query
sql_query = """
SELECT * FROM heat_pbp
WHERE home_name LIKE '%Heat%' and EVENTMSGTYPE = 1
"""

# Call the function with the SQL query
select_from_database(sql_query)
# Out:
# (22300587, 10, 1, 103, 1, '8:14 PM', '11:18', None, None, "Murray 26' 3PT Running Pull-Up Jump Shot (3 PTS)", '3 - 0', -3, 5, 1627749, 'Dejounte Murray', 1610612737, 'Atlanta', 'Hawks', 'ATL', 0, 0, None, None, None, None, None, 0, 0, None, None, None, None, None, 1, '2024-01-19T00:00:00', 1610612748, 1610612737, 'Miami Heat', 'Atlanta Hawks')
# (22300587, 58, 1, 1, 1, '8:14 PM', '11:02', "Martin 24' 3PT Jump Shot (3 PTS) (Herro 1 AST)", None, None, '3 - 3', 'TIE', 4, 1628997, 'Caleb Martin', 1610612748, 'Miami', 'Heat', 'MIA', 4, 1629639, 'Tyler Herro', 1610612748, 'Miami', 'Heat', 'MIA', 0, 0, None, None, None, None, None, 1, '2024-01-19T00:00:00', 1610612748, 1610612737, 'Miami Heat', 'Atlanta Hawks')
# ...

# %%
import requests


def get_highlight_url(game_id, event_id):
    headers = {
        'Host': 'stats.nba.com',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:72.0) Gecko/20100101 Firefox/72.0',
        'Accept': 'application/json, text/plain, */*',
        'Accept-Language': 'en-US,en;q=0.5',
        'Accept-Encoding': 'gzip, deflate, br',
        'x-nba-stats-origin': 'stats',
        'x-nba-stats-token': 'true',
        'Connection': 'keep-alive',
        'Referer': 'https://stats.nba.com/',
        'Pragma': 'no-cache',
        'Cache-Control': 'no-cache'
    }

    url = 'https://stats.nba.com/stats/videoeventsasset?GameEventID={}&GameID={}'.format(
                event_id, game_id)
    r = requests.get(url, headers=headers)
    json = r.json()
    print(json)

    video_urls = json['resultSets']['Meta']['videoUrls']
    playlist = json['resultSets']['playlist']
    video_event = {'video': video_urls[0]['lurl'], 'desc': playlist[0]['dsc']}
    return (video_event['video'],video_event['desc'])

get_highlight_url('0022301081',173)
# Out:
# {'resource': 'videoevents', 'parameters': {'GameID': '0022301081', 'GameEventID': 173}, 'resultSets': {'Meta': {'videoUrls': [{'uuid': '447ea013-1dba-2071-5db7-93838bb93781', 'sdur': 10883, 'surl': 'https://videos.nba.com/nba/pbp/media/2024/03/31/0022301081/173/447ea013-1dba-2071-5db7-93838bb93781_320x180.mp4', 'sth': 'https://videos.nba.com/nba/pbp/media/2024/03/31/0022301081/173/447ea013-1dba-2071-5db7-93838bb93781_320x180.jpg', 'mdur': 10883, 'murl': 'https://videos.nba.com/nba/pbp/media/2024/03/31/0022301081/173/447ea013-1dba-2071-5db7-93838bb93781_960x540.mp4', 'mth': 'https://videos.nba.com/nba/pbp/media/2024/03/31/0022301081/173/447ea013-1dba-2071-5db7-93838bb93781_960x540.jpg', 'ldur': 10883, 'lurl': 'https://videos.nba.com/nba/pbp/media/2024/03/31/0022301081/173/447ea013-1dba-2071-5db7-93838bb93781_1280x720.mp4', 'lth': 'https://videos.nba.com/nba/pbp/media/2024/03/31/0022301081/173/447ea013-1dba-2071-5db7-93838bb93781_1280x720.jpg', 'vtt': 'https://videos.nba.com/nba/pbp/me
# ...
